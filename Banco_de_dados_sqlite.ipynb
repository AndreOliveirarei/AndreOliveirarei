# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreOliveirarei/AndreOliveirarei/blob/main/Banco_de_dados_sqlite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://www.drawdb.app/editor?shareId=4c4052542b2dfb5deb0ec9d978b645fc

CREATE TABLE IF NOT EXISTS "vendas" (
    "id" INTEGER NOT NULL UNIQUE,
    "id_cliente" INTEGER NOT NULL,
    "id_produto" INTEGER NOT NULL,
    PRIMARY KEY("id", "id_cliente", "id_produto"),
    FOREIGN KEY ("id_produto") REFERENCES "produtos"("id_fonecedor")
    ON UPDATE NO ACTION ON DELETE NO ACTION,
    FOREIGN KEY ("id_cliente") REFERENCES "clientes"("id")
    ON UPDATE NO ACTION ON DELETE NO ACTION
);

CREATE TABLE IF NOT EXISTS "produtos" (
    "id" INTEGER NOT NULL UNIQUE,
    "nome" TEXT NOT NULL,
    "id_fonecedor" INTEGER NOT NULL,
    PRIMARY KEY("id", "id_fonecedor"),
    FOREIGN KEY ("id_fonecedor") REFERENCES "fornecedores"("id")
    ON UPDATE NO ACTION ON DELETE NO ACTION
);

CREATE TABLE IF NOT EXISTS "clientes" (
    "id" INTEGER NOT NULL UNIQUE,
    "nome" TEXT NOT NULL,
    PRIMARY KEY("id")
);

CREATE TABLE IF NOT EXISTS "fornecedores" (
    "id" INTEGER NOT NULL UNIQUE,
    "nome" TEXT NOT NULL,
    "cnpj" TEXT NOT NULL,
    PRIMARY KEY("id")
);
